# %% [markdown]
# <h1><center>Analyzing and Visualizing Report</center></h1>
# <center>By</center>
# <h3><center>Nishanth Iruthayaraj</center></h3>
#
# ###  Introduction

# %% [markdown]
# Real-world data rarely comes clean. Using Python and its libraries, we gathered data from a variety of sources and in a variety of formats, and assessed its quality and tidiness, then cleaned it. After the successfull completion of data wrangling, we also performed the anlyses on the wrangled data to find more insights. This report contains both the analysing and visualizing of our master dataset.

# %% [markdown]
# ### Analysing and Visualizing
# In general, there are multiple insights we can get from the master data we created. I have analysed the wrngled data and found the below 3 insights along with the visualization for clear understanding.
# <h5><center>What is the popular dog name?</center></h5>
# <h5><center>Which dog stage the is most common in the dog_stage group?</center></h5>
# <h5><center>Which type of breed is the most common breed?</center></h5>
#
# Let us dive deeper into each findings to understand the anaylsing along with the corresponding visaulization for each findings.

# %% [markdown]
# #### 1. What is the popular dog name?
# In our wrangled data, we have the one of the columns with name of dogs. In these names, there are repeated names of dogs. I also checked each type of names and found that there are two dogs named with just one letter **`a`** and **`O`**. It doesn't make any sense to name a dog with just one letter. So I added a letter **`M`** to each of them to name them as **`Ma`** **`MO`**and checked all the names of the dogs. The dog with the new name **`Ma`** becomes the most popular dog in the entire list of names. The below image shows the total counts of each dog names in the dataset.

# %% [markdown]
# ![Screenshot%202023-06-24%20122811.jpg](attachment:Screenshot%202023-06-24%20122811.jpg)

# %% [markdown]
# After ploting the above values with the help of Matplotlib library, we can see the clear visualization of popular dog name in the below image,
# ![Screenshot%202023-06-24%20122744.jpg](attachment:Screenshot%202023-06-24%20122744.jpg)

# %% [markdown]
# #### 2. Which dog stage the is most common in the dog_stage group?

# %% [markdown]
# In the original dataset twitter_archive, we had four columns for four different stages of dogs. These stages are doggo, pupper, puppo, and floof(er) and their meaning are shown in the below image,
# ![Screenshot%202023-06-24%20132442.jpg](attachment:Screenshot%202023-06-24%20132442.jpg)

# %% [markdown]
# Therefore I made a common column as dog_stage to combine all these four columns into single column. I used the programmatic implementation during the wrangling process. After combine all the dog stages, we found that there are many tweets without any information about the dog stage. Apart from that, the dog stage **`pupper`** is most common dog_stage in the entire tweets. The second and third position is taken by **`doggo`**, **`puppo`** and so on. It can be clearly seen in the below pie chart,
#
# ![Screenshot%202023-06-24%20122830-2.jpg](attachment:Screenshot%202023-06-24%20122830-2.jpg)

# %% [markdown]
# #### 3. Which type of breed is the most common breed?

# %% [markdown]
# In this finding, we get an insight about the common breed in the entire tweet. Unfortunately we also had variety of wrong predicitons like *jeep*, *ice_bear*, *African_grey*, etc. other than dogs. So during the wrangling process, we chose on the predictions related to dogs in order to find the most common breed in the entire tweets. After successful analysing, we get the count for most common breed as shown in the below figure,
# ![Screenshot%202023-06-24%20122927.jpg](attachment:Screenshot%202023-06-24%20122927.jpg)

# %% [markdown]
# Once we plot the above findings, the below visualization can be seen for the common breeds with thier corresponding values,
# ![Screenshot%202023-06-24%20122911.jpg](attachment:Screenshot%202023-06-24%20122911.jpg)
